# %% [markdown]
# ## 🎯 Wrap up
#
# **Fair coin is tossed 3 times. What is the probability of getting exactly 2 heads?**
#
# <details><summary><strong>Click to see solution</strong></summary>
#
# * Each toss has 2 outcomes: H (head), T (tail).
# * Total outcomes = $2^3 = 8$ (since 3 independent tosses).
# * Favorable = sequences with exactly 2 heads → {HHT, HTH, THH} = 3 outcomes.
# * Probability formula:
#
#   $$
#   P(E) = \frac{\text{Favorable}}{\text{Total}} = \frac{3}{8} = 0.375
#   $$
#
# ✅ **Answer = 0.375**
#
# </details>
#
# ---
#
# **A die is rolled once. What is the probability of getting a number greater than 4?**
#
# <details><summary>Click to see solution</summary>
#
# * Sample space = {1,2,3,4,5,6} → total = 6.
# * Favorable outcomes = {5,6} = 2.
# * Probability:
#
#   $$
#   P = \frac{2}{6} = \frac{1}{3} \approx 0.333
#   $$
#
# ✅ **Answer = 0.333**
#
# </details>
#
# ---
#
# **Q3. What is the probability of drawing an ace from a standard deck of 52 cards?**
#
# <details><summary>Click to see solution</summary>
#
# * A deck has 52 cards, 4 suits.
# * Each suit has 1 ace → total = 4 aces.
# * Probability:
#
#   $$
#   P = \frac{4}{52} = \frac{1}{13} \approx 0.0769
#   $$
#
# ✅ **Answer = 0.0769**
#
# </details>
#
# ---
#
# **Q4. A coin is biased such that probability of heads = 0.6. Find probability of getting exactly 1 head in 2 tosses.**
#
# <details><summary>Click to see solution</summary>
#
# * Use **Binomial distribution**:
#
#   $$
#   P(X=k) = \binom{n}{k} p^k (1-p)^{n-k}
#   $$
#
# * Here $n=2$, $k=1$, $p=0.6$.
#
# $$
# P(X=1) = \binom{2}{1} (0.6)^1 (0.4)^1 = 2 \times 0.6 \times 0.4 = 0.48
# $$
#
# ✅ **Answer = 0.48**
#
# </details>
#
# ---
#
# **Q5. A box has 3 red and 2 blue balls. If one ball is drawn, find probability of it being blue.**
#
# <details><summary>Click to see solution</summary>
#
# * Total balls = 3 + 2 = 5.
# * Favorable = blue = 2.
#
# $$
# P = \frac{2}{5} = 0.4
# $$
#
# ✅ **Answer = 0.4**
#
# </details>
#
# ---
#
#
# ## 🟡 Intermediate Level
#
# **Q6. A box contains 5 red balls and 7 blue balls. If 2 are drawn without replacement, what is probability both are red?**
#
# <details><summary>Click to see solution</summary>
#
# * Total balls = 12. Ways to choose 2 = $\binom{12}{2}=66$.
# * Favorable = choose 2 red out of 5 = $\binom{5}{2}=10$.
#
# $$
# P = \frac{10}{66} = \frac{5}{33} \approx 0.1515
# $$
#
# ✅ **Answer = 0.1515**
#
# </details>
#
# ---
#
# **Q7. If two independent events A and B have P(A)=0.4, P(B)=0.5, find P(A ∪ B).**
#
# <details><summary>Click to see solution</summary>
#
# * Formula for union of independent events:
#
# $$
# P(A ∪ B) = P(A) + P(B) - P(A)P(B)
# $$
#
# * Substitute:
#
# $$
# = 0.4 + 0.5 - (0.4 \times 0.5) = 0.7
# $$
#
# ✅ **Answer = 0.7**
#
# </details>
#
# ---
#
# **Q8. A fair die is rolled twice. Find probability that sum = 7.**
#
# <details><summary>Click to see solution</summary>
#
# * Total outcomes = $6 \times 6 = 36$.
# * Favorable pairs = {(1,6),(2,5),(3,4),(4,3),(5,2),(6,1)} = 6.
#
# $$
# P = \frac{6}{36} = \frac{1}{6} \approx 0.1667
# $$
#
# ✅ **Answer = 0.1667**
#
# </details>
#
# ---
#
# **Q9. A family has 2 children. Find probability that both are girls given at least one is girl.**
#
# <details><summary>Click to see solution</summary>
#
# * Sample space = {BB, BG, GB, GG}.
# * Condition: ≥1 girl → {BG, GB, GG} (exclude BB).
# * Favorable = {GG}.
#
# $$
# P = \frac{1}{3} \approx 0.333
# $$
#
# ✅ **Answer = 0.333**
#
# </details>
#
# ---
#
# **Q10. A bag contains 8 white and 6 black balls. Two balls drawn with replacement. Probability both are black?**
#
# <details><summary>Click to see solution</summary>
#
# * $P(black) = \frac{6}{14} = \frac{3}{7}$.
# * With replacement → independent.
#
# $$
# P = \left(\frac{3}{7}\right)^2 = \frac{9}{49} \approx 0.1837
# $$
#
# ✅ **Answer = 0.1837**
#
# </details>
#
# ---
#
# **Q11. In a class, 60% are boys, 40% girls. If 70% of boys and 80% of girls passed, find probability that a student chosen at random has passed.**
#
# <details><summary>Click to see solution</summary>
#
# * Law of Total Probability:
#
# $$
# P(pass) = P(pass|boy)P(boy) + P(pass|girl)P(girl)
# $$
#
# * \= (0.7×0.6) + (0.8×0.4) = 0.42 + 0.32 = 0.74.
#
# ✅ **Answer = 0.74**
#
# </details>
#
# ---
#
# **Q12. A fair die is rolled until a 6 appears. What is the expected number of rolls?**
#
# <details><summary>Click to see solution</summary>
#
# * Follows **Geometric distribution** with success probability $p=1/6$.
# * Expectation formula:
#
# $$
# E[X] = \frac{1}{p} = \frac{1}{1/6} = 6
# $$
#
# ✅ **Answer = 6**
#
# </details>
#
# ---
#
# ---
#
# ## 🔴 Hard Level
#
# **Q13. If 5% of population has a disease, test detects correctly 98% of sick, false positive rate 2%. If person tests positive, what is probability he has disease? (Bayes)**
#
# <details><summary>Click to see solution</summary>
#
# * Let D = disease, T+ = test positive.
# * $P(D)=0.05$, $P(\sim D)=0.95$.
# * $P(T+|D)=0.98$, $P(T+|\sim D)=0.02$.
# * By **Bayes’ Theorem**:
#
# $$
# P(D|T+) = \frac{P(T+|D)P(D)}{P(T+|D)P(D)+P(T+|\sim D)P(\sim D)}
# $$
#
# Substitute:
#
# $$
# = \frac{0.98 \times 0.05}{(0.98 \times 0.05)+(0.02 \times 0.95)} = 0.7206
# $$
#
# ✅ **Answer = 72.1%**
#
# </details>
#
# ---
#
# **Q14. A die is rolled twice. Find probability first roll > second roll.**
#
# <details><summary>Click to see solution</summary>
#
# * Total outcomes = 36.
# * For each value of second roll, count possible larger first rolls:
#
#   * If 2 → first can be {3,4,5,6} (4 ways)
#   * If 3 → {4,5,6} (3 ways)
#   * If 4 → {5,6} (2 ways)
#   * If 5 → {6} (1 way)
#   * If 6 → none (0).
# * Total favorable = 1+2+3+4+5 = 15.
#
# $$
# P = \frac{15}{36} = \frac{5}{12} \approx 0.4167
# $$
#
# ✅ **Answer = 0.4167**
#
# </details>
#
# ---
#
# **Q15. A box has 4 defective and 6 good bulbs. Two drawn without replacement. What is probability at least one defective?**
#
# <details><summary>Click to see solution</summary>
#
# * Total ways = $\binom{10}{2}=45$.
# * Complement = none defective = choose 2 good bulbs = $\binom{6}{2}=15$.
# * So favorable = 45 – 15 = 30.
#
# $$
# P = \frac{30}{45} = \frac{2}{3} \approx 0.667
# $$
#
# ✅ **Answer = 0.667**
#
# </details>
#
# ---
#
# **Q16. Random variable $X \sim Binomial(n=10, p=0.3)$. Find $P(X=4)$.**
#
# <details><summary>Click to see solution</summary>
#
# * Binomial formula:
#
# $$
# P(X=k) = \binom{n}{k} p^k (1-p)^{n-k}
# $$
#
# * $n=10, k=4, p=0.3$:
#
# $$
# P(X=4) = \binom{10}{4} (0.3)^4 (0.7)^6
# $$
#
# $$
# = 210 \times 0.0081 \times 0.1176 \approx 0.2001
# $$
#
# ✅ **Answer = 0.20**
#
# </details>
#
# ---
#
# **Q17. For a standard normal variable $Z$, find $P(-1.96 \le Z \le 1.96)$.**
#
# <details><summary>Click to see solution</summary>
#
# * From Z-table:
#
#   * $P(Z \le 1.96) = 0.975$
#   * $P(Z \le -1.96) = 0.025$
# * So probability between:
#
# $$
# = 0.975 - 0.025 = 0.95
# $$
#
# ✅ **Answer = 0.95**
#
# </details>
#
# ---
#
# **Q18. If $X \sim Exponential(\lambda=2)$, find mean and variance.**
#
# <details><summary>Click to see solution</summary>
#
# * Properties:
#
#   * Mean = $1/\lambda$
#   * Variance = $1/\lambda^2$
# * For $\lambda=2$:
#
# $$
# Mean = \frac{1}{2}=0.5, \quad Var = \frac{1}{4}=0.25
# $$
#
# ✅ **Answer = Mean=0.5, Var=0.25**
#
# </details>
#
# ---
#
# **Q19. If $X \sim Uniform(0,1)$, find probability $(X > 0.7)$.**
#
# <details><summary>Click to see solution</summary>
#
# * Uniform distribution has equal probability density.
# * Probability = length of interval / total length.
# * $(0.7,1)$ has length 0.3.
#
# $$
# P(X>0.7)=0.3
# $$
#
# ✅ **Answer = 0.3**
#
# </details>
#
# ---
#
# **Q20. (Tough!) Suppose we flip a fair coin 100 times. Using CLT, approximate probability of getting more than 60 heads.**
#
# <details><summary>Click to see solution</summary>
#
# * $X \sim Binomial(n=100, p=0.5)$.
# * Mean = $np=50$, Variance = $npq=25$, SD=5.
# * By CLT, approximate with Normal.
# * Standardize:
#
# $$
# P(X>60) \approx P\left(Z > \frac{60-50}{5}\right) = P(Z>2)
# $$
#
# * From Z-table: $P(Z>2)=0.0228$. (i.e 1-zscore(2))
#
# ✅ **Answer = 2.28%**
#
# </details>
