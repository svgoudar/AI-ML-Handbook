# %% [markdown]
# ```{contents}
#
# ```

# %% [markdown]
# ## Confidence Interval (CI) & Margin of Error
#
# * **Confidence Interval**: A range of values around a sample mean ($\bar{x}$) that likely contains the population mean ($\mu$) with a given confidence level.
# * **Formula**:
#
#   $$
#   CI = \bar{x} \pm \text{Margin of Error}
#   $$
#
# ---
#
# ## Key Concepts
#
# 1. **Point Estimate**:
#
#    * Sample mean ($\bar{x}$) is used to estimate the population mean.
#    * Limitation: Different samples may give different means.
#
# 2. **Confidence Interval**:
#
#    * Instead of a single point estimate, we calculate a **range** where the true mean is likely to lie.
#    * CI depends on:
#
#      * Confidence level (e.g., 95%)
#      * Standard deviation
#      * Sample size
#      * Z or T distribution
#
# 3. **Margin of Error (ME)**:
#
#    * Accounts for variation around the sample mean.
#    * **For Z-test** (when population σ is known):
#
#      $$
#      ME = Z_{\alpha/2} \times \frac{\sigma}{\sqrt{n}}
#      $$
#    * **For T-test** (when σ unknown):
#
#      $$
#      ME = t_{\alpha/2, df} \times \frac{s}{\sqrt{n}}
#      $$
#
# ---
#
# ## Example (CAT Exam Scores)
#
# * Population standard deviation (σ) = 100
# * Sample size (n) = 25
# * Sample mean ($\bar{x}$) = 520
# * Confidence level = 95% → $Z_{\alpha/2} = 1.96$
#
# **Step 1: Calculate Margin of Error**
#
# $$
# ME = 1.96 \times \frac{100}{\sqrt{25}} = 39.2
# $$
#
# **Step 2: Confidence Interval**
#
# * Lower bound = $520 - 39.2 = 480.8$
# * Upper bound = $520 + 39.2 = 559.2$
#
# ✅ **Interpretation**: We are **95% confident** that the average CAT exam score lies between **480.8 and 559.2**.
#
# ---
#
# ## Final Takeaway
#
# * CI gives a **range estimate** instead of a single value.
# * Wider intervals = more uncertainty, narrower = more precise.
# * Z-test (σ known) → use Z table.
# * T-test (σ unknown) → use T table with degrees of freedom.
